# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df["sex"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df["smoker"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df["smoker"].value_counts().plot(kind='pie',autopct='%1.1f%%')

# %% [markdown]
# ## Which day had highest tips, at specific part of the day?

# %%
sns.barplot(data=df, x="day",y="tip",hue="time")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# <h4>Note:</h4>
# <p>We discovered that <b> lunch is not being served  at weekend.</b></p>

# %% [markdown]
# ## What about tip on each day based on size?

# %%
sns.barplot(data=df, x="day",y="tip",hue="size")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## I would like to have same results, but about total bill, this time

# %% [markdown]
# ### Total bill on each day based by smoker category

# %%
sns.barplot(data=df, x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Total bill of each day based on time

# %%
sns.barplot(data=df, x="day",y="total_bill",hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Total bill each day based on gender

# %%
sns.barplot(data=df, x="day",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Total bill of each day based on size

# %%
sns.barplot(data=df, x="day",y="total_bill",hue="size")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Total bill skewness

# %%
sns.histplot(data=df,x="total_bill",bins=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tb_mean = df["total_bill"].mean()
tb_med = df["total_bill"].median()
if tb_mean > tb_med:
    print("Mean > Median - positive skewness")
elif tb_mean < tb_med:
     print("Mean > Median - positive skewness")
else:
     print("Mean ~= Median - uniform skewness")
# Out:
# Mean > Median - positive skewness

# %%
df["total_bill"].mean()
# Out:
# 19.78594262295082

# %%
df["total_bill"].median()
# Out:
# 17.795

# %%
sns.countplot(df, x="day", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt.title("Number of times that male or female paid, in relation to size of group")
sns.countplot(df, x="size", hue="sex")
plt.show()

# %%
df["size"].median()
# Out:
# 2.0

# %%
sns.countplot(df,x="day", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>
